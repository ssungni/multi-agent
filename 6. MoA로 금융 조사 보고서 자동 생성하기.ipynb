# %% [markdown]
# # MoA로 금융 조사 보고서 자동 생성하기

# %% [markdown]
# - MoA: Mixture of Agents
#     - 여러개의 agent를 돌려서 결과물을 얻는 것
#     - ex) genspark
#     - 장점: 편향된 사고를 줄일 수 있음

# %% [markdown]
# # 1. API 설정

# %%
import os
from dotenv import load_dotenv

load_dotenv()
