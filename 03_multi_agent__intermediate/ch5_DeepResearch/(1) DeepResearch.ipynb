# %% [markdown]
# - planning을 거쳐 search task 수행하는 것은 동일

# %% [markdown]
# 1. Main
# (1) clarify_with_user
# - 너가 말하는 질문이 맞는거야? 확인
#
#
# 2. Supervisor
#
#
# 3. Researcher

# %% [markdown]
# - Genspark
# - Manus
#     - 계획 수립, 컨텍스트 관리, 하위 에이전트, 장기기억
